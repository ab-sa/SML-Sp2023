# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import Ridge, RidgeCV, Lasso, LassoCV
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, RepeatedKFold
#import statsmodels.formula.api as smf
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Credit = pd.read_csv('Credit.csv')
#Insurance = pd.read_csv('Insurance.csv')
print('Dimension of the data: ' + str(Credit.shape))
Credit.head()
# Out:
# Dimension of the data: (400, 12)
#    ID   Income  Limit  Rating  Cards  Age  Education  Gender Student Married  \
# 0   1   14.891   3606     283      2   34         11    Male      No     Yes
# 1   2  106.025   6645     483      3   82         15  Female     Yes     Yes
# 2   3  104.593   7075     514      4   71         11    Male      No      No
# 3   4  148.924   9504     681      3   36         11  Female      No      No
# 4   5   55.882   4897     357      2   68         16    Male      No     Yes
#
#    Ethnicity  Balance
# 0  Caucasian      333
# 1      Asian      903
# 2      Asian      580
# 3      Asian      964
# 4  Caucasian      331

# %%
Credit_dumms = pd.get_dummies(Credit)
y = Credit_dumms['Balance']
X = Credit_dumms.drop(['ID', 'Balance'], axis=1)

X_train, X_test , y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

std_scale = StandardScaler().fit(X_train)
X_train_std = std_scale.transform(X_train)
X_test_std  = std_scale.transform(X_test)

# %%
X_temp = X_train[['Limit', 'Rating', 'Cards', 'Age', 'Education']]
std_scale_temp = StandardScaler().fit(X_temp)
X_temp_std = std_scale_temp.transform(X_temp)

LMRidge = Ridge(alpha=1.0)
print(LMRidge.fit(X_temp, y_train).coef_)
print(LMRidge.fit(X_temp_std, y_train).coef_)
# Out:
# [ 0.08097534  1.4132531  19.78523476 -1.91165513  2.72674614]
# [191.49696239 203.88383002  28.46754314 -33.91630484   8.50066239]

# %%
# model evaluation: coss validation
CV10 = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
LMRidgeCV = RidgeCV(alphas=np.arange(0, 1, 0.01), cv=CV10, scoring='neg_mean_squared_error')
LMRidgeCV.fit(X_train_std, y_train)
# summarize chosen configuration
print('alpha: %f' % LMRidgeCV.alpha_)
# Out:
# alpha: 0.990000

# %%
LMRidge = Ridge(alpha = LMRidgeCV.alpha_)
LMRidge.fit(X_train_std, y_train)
mean_squared_error(y_test, LMRidge.predict(X_test_std))
print(LMRidge.coef_)
# Out:
# [-2.63602616e+02  3.00726992e+02  2.94312336e+02  1.72299223e+01
#  -1.51265357e+01 -1.47653387e+00 -1.54251687e-01  1.54251687e-01
#  -6.31311706e+01  6.31311706e+01  4.28401812e-01 -4.28401812e-01
#  -5.79187696e+00  6.30982287e+00 -5.96078677e-01]

# %%
LMLassoCV = LassoCV(alphas = np.arange(0, 1, 0.01), cv = CV10, max_iter = 1000)
LMLassoCV.fit(X_train_std, y_train)
print(LMLassoCV.alpha_)

LMLasso = Lasso(max_iter = 10000)
LMLasso.set_params(alpha=LMLassoCV.alpha_)
LMLasso.fit(X_train_std, y_train)
mean_squared_error(y_test, LMLasso.predict(X_test_std))
print(LMLasso.coef_)
# Out:
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1125137.0632613823, tolerance: 5041.904896428572
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1124311.1558177099, tolerance: 5266.130465079366
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1147811.9354745075, tolerance: 5163.603125000001
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1152349.1357162297, tolerance: 5030.094542857143
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1138365.3383223861, tolerance: 5214.841485714285
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1031750.4664956033, tolerance: 5126.803093650795
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1042753.8932981044, tolerance: 5316.1179250000005
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1076034.7727835625, tolerance: 5149.490096428571
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1143767.2178852633, tolerance: 5172.5905936507925
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1134222.7413379028, tolerance: 5302.6096964285725
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1091776.6905163154, tolerance: 5068.096725
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1057412.1136566997, tolerance: 5283.85090793651
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1152089.3423503712, tolerance: 5220.208560317461
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1097855.4674907103, tolerance: 5200.247410714286
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1140527.219363995, tolerance: 5234.406318650795
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1068594.7942195684, tolerance: 4916.424971428572
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1141817.650385365, tolerance: 5199.632031746032
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1116700.470612906, tolerance: 5234.275899603175
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1104152.0044683814, tolerance: 5241.692667857142
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1153935.4086847827, tolerance: 5172.284007936508
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1134525.6413958967, tolerance: 5263.216232936507
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1164633.1511041448, tolerance: 5034.4228079365075
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1012511.8527196497, tolerance: 5207.466525000001
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1108555.9751818106, tolerance: 5188.814251984126
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1138712.2191347405, tolerance: 5273.8325186507955
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1054341.1735575423, tolerance: 5171.914610714287
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# 0.99
# [-2.63863031e+02  3.03949746e+02  2.91323960e+02  1.64529674e+01
#  -1.42079560e+01 -5.81108303e-01 -0.00000000e+00  0.00000000e+00
#  -1.25577343e+02  1.86854468e-11  0.00000000e+00 -0.00000000e+00
#  -4.49275741e+00  6.20221002e+00 -0.00000000e+00]
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1089052.8381725475, tolerance: 5009.069341269842
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1158347.1645008326, tolerance: 5131.598651984126
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1131833.8735860884, tolerance: 5330.74669642857
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: UserWarning: Coordinate descent with alpha=0 may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\users\arab\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:633: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1107402.498596102, tolerance: 5140.105493650795
#   model = cd_fast.enet_coordinate_descent_gram(
